# %%
import csv
import re
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
## file name and setup 

file_name = 'index'

#pollutants
terms_of_interest = ['carcinogenic', 'carcinogens', 'arsenic', 'nitrate', 'nitrite', 'nitrates']

#urls
basic_url = 'https://www.communitywatercenter.org/news?n=448&page='
n_pages = 34

#cities
location_names = pd.read_csv('CA_names.csv')

# %%
pagelinks =[]

for number in range(1,n_pages+1):

    url = basic_url + str(number)
    page = urlopen(url)
    soup = BeautifulSoup(page, 'html.parser') #containing the HTML of the page
    name_box = soup.find_all('h3', attrs={'class': 'news_heading'})
    for count in range(0, len(name_box)):
            for link in name_box[count].find_all('a', href=True):
                pagelinks.append(link['href'])

# %%
# For finding cities and counties

cities = location_names['city'].tolist() 
#counties = location_names['county_name'].tolist()
counties = ['Tulare', 'Kern']

## hack solution to control for weird city names matching words

cities.remove('August')
cities.remove('Challenge')
#locations = cities + counties

#creating regex expressions
re_cities = '' + cities[0]
for i in cities[1:]:
    re_cities = re_cities + "|" + i
re_counties = '' + counties[0]
for i in counties[1:]:
    re_counties = re_counties + "|" + i
    
def intersect(a, b):
     return list(set(a) & set(b))
    
def most_common(lst):
    return max(set(lst), key=lst.count)

# %%
# Writing to CSV file (basic)

data = []

for count in range(0, len(pagelinks)):
    
    page_url = "https://www.communitywatercenter.org" + pagelinks[count]
    page = urlopen(page_url)
    soup = BeautifulSoup(page, 'html.parser')
    main = soup.find("div", id="content").text.strip()
    
    title = soup.title.string.replace('\r', '').replace('\n', '')
    date_section = soup.find('div', id="headline")
    date = date_section.find_all(string=re.compile("Published on"))
    
    list_city = re.findall(re_cities, main)
    list_county = re.findall(re_counties, main)
    if len(list_city) > 0:
        main_city = most_common(list_city)
    else:
        main_city = ""
    if len(list_county) > 0:
        main_county = most_common(list_county)
    else:
        main_county = ""
    
    city = list(set(list_city))
    county = list(set(list_county))
    
    for term in range(0, len(terms_of_interest)):

            phrase = [(sentence + '.').replace('\r', '').replace('\n', '') for sentence in main.split('.') if terms_of_interest[term] in sentence]

            for item in range(0, len(phrase)):

                data.append([phrase[item], terms_of_interest[term], str(date)[19:-8], city, county, main_city, main_county, title, page_url])
                
phrase_df = pd.DataFrame(data, columns = ["phrase", "contaminant", "date", "city", "county","main city","main county", "title", "page_url"])
               
#     with open(file_name + '.csv', 'a') as mycsv: ## a for append
        
#         writer = csv.writer(mycsv)
        
#         for term in range(0, len(terms_of_interest)):

#             phrase = [sentence + '.' for sentence in main.split('.') if terms_of_interest[term] in sentence]

#             for item in range(0, len(phrase)):

#                 writer.writerow([phrase[item], str(date)[19:-8], city, county, title, page_url])
# Out:
#                                               phrase   contaminant  \
# 0   NEW OFFICE IN WATSONVILLE, CAWe are excited t...       nitrate
# 1  Bartolo Chavez of Arvin, CA has drinking water...  carcinogenic
# 2  Bartolo Chavez of Arvin, CA has drinking water...       arsenic
# 3  org #NoToxicTaps1,2,3 - TCP1,2,3-trichloroprop...  carcinogenic
# 4   Over 300 mostly rural and economically disadv...       arsenic
#
#                  date                                               city  \
# 0  September 17, 2018  [Watsonville, Fresno, San Joaquin, Porterville...
# 1  September 06, 2018                                            [Arvin]
# 2  September 06, 2018                                            [Arvin]
# 3       July 31, 2018  [Orosi, Tulare, Fresno, San Joaquin, Portervil...
# 4    October 24, 2017                                                 []
#
#            county    main city main county  \
# 0              []      Visalia
# 1              []        Arvin
# 2              []        Arvin
# 3  [Kern, Tulare]  Porterville      Tulare
# 4              []
#
#                                                title  \
# 0         August 2018 eNews - Community Water Center
# 1           Justice Delayed - Community Water Center
# 2           Justice Delayed - Community Water Center
# 3           July 2018 eNews - Community Water Center
# 4  Small Communities Can't Solve Toxic Water Prob...
#
#                                             page_url
# 0  https://www.communitywatercenter.org/august201...
# 1  https://www.communitywatercenter.org/justicede...
# 2  https://www.communitywatercenter.org/justicede...
# 3  https://www.communitywatercenter.org/july_2018...
# 4  https://www.communitywatercenter.org/toxic_wat...

# %%
ids = phrase_df["phrase"]
phrase_df[ids.isin(ids[ids.duplicated()])]#.sort("phrase")
# Out:
#                                                 phrase    contaminant  \
# 1    Bartolo Chavez of Arvin, CA has drinking water...  carcinogenic
# 2    Bartolo Chavez of Arvin, CA has drinking water...       arsenic
# 4     Over 300 mostly rural and economically disadv...       arsenic
# 5     Over 300 mostly rural and economically disadv...       nitrate
# 6     Over 300 mostly rural and economically disadv...      nitrates
# 9     Waiting until the next legislative session wo...       arsenic
# 10    Waiting until the next legislative session wo...       nitrate
# 11    Waiting until the next legislative session wo...      nitrates
# 12    Some area's water containing over three times...   carcinogens
# 13    Some area's water containing over three times...       arsenic
# 18    “But having arsenic, nitrate or pesticides fl...       arsenic
# 20    “But having arsenic, nitrate or pesticides fl...       nitrate
# 21    Drinking water with contaminants like arsenic...       arsenic
# 22    Drinking water with contaminants like arsenic...       nitrate
# 26    In California, most of the drinking water con...       arsenic
# 27    In California, most of the drinking water con...       nitrate
# 28    In California, most of the drinking water con...      nitrates
# 29    Glenwood's well was contaminated with nitrate...       nitrate
# 30   There is a happy ending to the story: Glenwood...       nitrate
# 32    County officials said the health risk pertain...       nitrate
# 33    Glenwood's well was contaminated with nitrate...      nitrates
# 34   There is a happy ending to the story: Glenwood...      nitrates
# 35    County officials said the health risk pertain...      nitrates
# 37   , where lead contamination made headlines, “a ...       arsenic
# 39   , where lead contamination made headlines, “a ...       nitrate
# 41   Assemblyman Devon Mathis, R-Visalia, whose dis...       nitrate
# 42   “There are people coming down with rashes due ...       nitrate
# 44   , where lead contamination made headlines, “a ...      nitrates
# 45   Assemblyman Devon Mathis, R-Visalia, whose dis...      nitrates
# 46   “There are people coming down with rashes due ...      nitrates
# ..                                                 ...            ...
# 302  According to Peter Weyer, associate director o...      nitrates
# 303   In adults, long-term exposure to nitrates can...      nitrates
# 304   But if you boil the water you concentrate the...      nitrates
# 306  6 million people in the Tulare Lake Basin and ...       nitrate
# 307  6 million people in the Tulare Lake Basin and ...      nitrates
# 313   Well monitoring has shown high levels of nitr...       nitrate
# 314   Well monitoring has shown high levels of nitr...      nitrates
# 321   “Arsenic is a widespread issue, as well as ni...       nitrate
# 325  Partnership Brings Clean Drinking Water to Cen...
# 326  Partnership Brings Clean Drinking Water to Cen...
# 327  Partnership Brings Clean Drinking Water to Cen...
# 329  South Kern County schools get safe drinking wa...
# 331  South Kern County schools get safe drinking wa...
# 335  Safer water for schools in Arvin and Lamont - ...
# 336  Safer water for schools in Arvin and Lamont - ...
# 337  Safer water for schools in Arvin and Lamont - ...
# 339  Press Release: Schools with arsenic contaminat...
# 342  Press Release: Schools with arsenic contaminat...
# 344  Water unaffordable to some in San Joaquin Vall...
# 345  Water unaffordable to some in San Joaquin Vall...
# 346  Water unaffordable to some in San Joaquin Vall...
# 347  Water unaffordable to some in San Joaquin Vall...
# 348  Water unaffordable to some in San Joaquin Vall...
# 350  Often-tainted tap water unaffordable to many i...
# 352  Often-tainted tap water unaffordable to many i...
# 353  Tulare County water districts take first steps...
# 354  Tulare County water districts take first steps...
# 355  Tulare County water districts take first steps...
#
#                                               page_url new_contaminant
# 1    https://www.communitywatercenter.org/justicede...   carcinogenic
# 2    https://www.communitywatercenter.org/justicede...        arsenic
# 4    https://www.communitywatercenter.org/toxic_wat...        arsenic
# 5    https://www.communitywatercenter.org/toxic_wat...        nitrate
# 6    https://www.communitywatercenter.org/toxic_wat...       nitrates
# 9      https://www.communitywatercenter.org/kvpr_sb623        arsenic
# 10     https://www.communitywatercenter.org/kvpr_sb623        nitrate
# 11     https://www.communitywatercenter.org/kvpr_sb623       nitrates
# 12   https://www.communitywatercenter.org/toxic_sch...    carcinogens
# 13   https://www.communitywatercenter.org/toxic_sch...        arsenic
# 18   https://www.communitywatercenter.org/revisedbu...        arsenic
# 20   https://www.communitywatercenter.org/revisedbu...        nitrate
# 21   https://www.communitywatercenter.org/sb623_senate        arsenic
# 22   https://www.communitywatercenter.org/sb623_senate        nitrate
# 26   https://www.communitywatercenter.org/drinking_...        arsenic
# 27   https://www.communitywatercenter.org/drinking_...        nitrate
# 28   https://www.communitywatercenter.org/drinking_...       nitrates
# 29   https://www.communitywatercenter.org/the_chall...        nitrate
# 30   https://www.communitywatercenter.org/the_chall...        nitrate
# 32   https://www.communitywatercenter.org/the_chall...        nitrate
# 33   https://www.communitywatercenter.org/the_chall...       nitrates
# 34   https://www.communitywatercenter.org/the_chall...       nitrates
# 35   https://www.communitywatercenter.org/the_chall...       nitrates
# 37   https://www.communitywatercenter.org/clean_wat...        arsenic
# 39   https://www.communitywatercenter.org/clean_wat...        nitrate
# 41   https://www.communitywatercenter.org/clean_wat...        nitrate
# 42   https://www.communitywatercenter.org/clean_wat...        nitrate
# 44   https://www.communitywatercenter.org/clean_wat...       nitrates
# 45   https://www.communitywatercenter.org/clean_wat...       nitrates
# 46   https://www.communitywatercenter.org/clean_wat...       nitrates
# ..                                                 ...             ...
# 302  https://www.communitywatercenter.org/californi...       nitrates
# 303  https://www.communitywatercenter.org/californi...       nitrates
# 304  https://www.communitywatercenter.org/californi...       nitrates
# 306  https://www.communitywatercenter.org/legislati...        nitrate
# 307  https://www.communitywatercenter.org/legislati...       nitrates
# 313  https://www.communitywatercenter.org/epa_head_...        nitrate
# 314  https://www.communitywatercenter.org/epa_head_...       nitrates
# 321  https://www.communitywatercenter.org/partnersh...        nitrate
# 322  https://www.communitywatercenter.org/partnersh...        nitrate
# 324  https://www.communitywatercenter.org/partnersh...        nitrate
# 325  https://www.communitywatercenter.org/partnersh...       nitrates
# 326  https://www.communitywatercenter.org/partnersh...       nitrates
# 327  https://www.communitywatercenter.org/partnersh...       nitrates
# 329  https://www.communitywatercenter.org/south_ker...        arsenic
# 331  https://www.communitywatercenter.org/south_ker...        nitrate
# 335  https://www.communitywatercenter.org/safer_wat...        arsenic
# 336  https://www.communitywatercenter.org/safer_wat...        nitrate
# 337  https://www.communitywatercenter.org/safer_wat...       nitrates
# 339  https://www.communitywatercenter.org/press_rel...        arsenic
# 342  https://www.communitywatercenter.org/press_rel...        nitrate
# 344  https://www.communitywatercenter.org/water_una...        arsenic
# 345  https://www.communitywatercenter.org/water_una...        nitrate
# 346  https://www.communitywatercenter.org/water_una...        nitrate
# 347  https://www.communitywatercenter.org/water_una...       nitrates
# 348  https://www.communitywatercenter.org/water_una...       nitrates
# 350  https://www.communitywatercenter.org/often_tai...        nitrate
# 352  https://www.communitywatercenter.org/often_tai...       nitrates
# 353  https://www.communitywatercenter.org/tulare_co...        arsenic
# 354  https://www.communitywatercenter.org/tulare_co...        nitrate
# 355  https://www.communitywatercenter.org/tulare_co...       nitrates
#
# [224 rows x 10 columns]

# %%
phrase_df.head()
# Out:
#                                               phrase    contaminant  \
# 0   NEW OFFICE IN WATSONVILLE, CAWe are excited t...       nitrate
# 1  Bartolo Chavez of Arvin, CA has drinking water...  carcinogenic
# 2  Bartolo Chavez of Arvin, CA has drinking water...       arsenic
# 3  org #NoToxicTaps1,2,3 - TCP1,2,3-trichloroprop...  carcinogenic
# 4   Over 300 mostly rural and economically disadv...       arsenic
#
#                  date                                               city  \
# 0  September 17, 2018  [Watsonville, Fresno, San Joaquin, Porterville...
# 1  September 06, 2018                                            [Arvin]
# 2  September 06, 2018                                            [Arvin]
# 3       July 31, 2018  [Orosi, Tulare, Fresno, San Joaquin, Portervil...
# 4    October 24, 2017                                                 []
#
#            county    main city main county  \
# 0              []      Visalia
# 1              []        Arvin
# 2              []        Arvin
# 3  [Kern, Tulare]  Porterville      Tulare
# 4              []
#
#                                                title  \
# 0         August 2018 eNews - Community Water Center
# 1           Justice Delayed - Community Water Center
# 2           Justice Delayed - Community Water Center
# 3           July 2018 eNews - Community Water Center
# 4  Small Communities Can't Solve Toxic Water Prob...
#
#                                             page_url new_contaminant
# 0  https://www.communitywatercenter.org/august201...        nitrate
# 1  https://www.communitywatercenter.org/justicede...   carcinogenic
# 2  https://www.communitywatercenter.org/justicede...        arsenic
# 3  https://www.communitywatercenter.org/july_2018...   carcinogenic
# 4  https://www.communitywatercenter.org/toxic_wat...        arsenic

# %%
phrase_df.to_csv("phrase.csv")

# %%
#read csv
output = pd.read_csv('phrase.csv')
# isolate phrases without location

# %%
## for data analysis %load_ext rpy2.ipython
